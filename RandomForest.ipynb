# %%
# This random forest will contain non-numeric feature columns also

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
pd.set_option('display.max_columns', None)

# %%
train_df = pd.read_csv('dengue_features_train.csv')
train_label_df = pd.read_csv('dengue_labels_train.csv')
test_df = pd.read_csv('dengue_features_test.csv')
test_orig_df = pd.DataFrame(test_df)

# %%
train_df
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0      sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1      sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2      sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3      sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4      sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
# 5      sj  1990          23      1990-06-04       NaN  0.174850  0.254314
# 6      sj  1990          24      1990-06-11  0.112900  0.092800  0.205071
# 7      sj  1990          25      1990-06-18  0.072500  0.072500  0.151471
# 8      sj  1990          26      1990-06-25  0.102450  0.146175  0.125571
# 9      sj  1990          27      1990-07-02       NaN  0.121550  0.160683
# 10     sj  1990          28      1990-07-09  0.192875  0.082350  0.191943
# 11     sj  1990          29      1990-07-16  0.291600  0.211800  0.301200
# ...

# %%
#Fill in all empty entries in training and test data

# %%
train_df['ndvi_ne'].fillna(train_df.ndvi_ne.mean(), inplace = True)
train_df['ndvi_nw'].fillna(train_df.ndvi_nw.mean(), inplace = True)
train_df['ndvi_se'].fillna(train_df.ndvi_se.mean(), inplace = True)
train_df['ndvi_sw'].fillna(train_df.ndvi_sw.mean(), inplace = True)
train_df['precipitation_amt_mm'].fillna(train_df.precipitation_amt_mm.mean(), inplace = True)
train_df['reanalysis_air_temp_k'].fillna(train_df.reanalysis_air_temp_k.mean(), inplace = True)
train_df['reanalysis_avg_temp_k'].fillna(train_df.reanalysis_avg_temp_k.mean(), inplace = True)
train_df['reanalysis_dew_point_temp_k'].fillna(train_df.reanalysis_max_air_temp_k.mean(), inplace = True)
train_df['reanalysis_max_air_temp_k'].fillna(train_df.reanalysis_dew_point_temp_k.mean(), inplace = True)
train_df['reanalysis_min_air_temp_k'].fillna(train_df.reanalysis_min_air_temp_k.mean(), inplace = True)
train_df['reanalysis_precip_amt_kg_per_m2'].fillna(train_df.reanalysis_precip_amt_kg_per_m2.mean(), inplace = True)
train_df['reanalysis_relative_humidity_percent'].fillna(train_df.reanalysis_relative_humidity_percent.mean(), inplace = True)
train_df['reanalysis_sat_precip_amt_mm'].fillna(train_df.reanalysis_sat_precip_amt_mm.mean(), inplace = True)
train_df['reanalysis_specific_humidity_g_per_kg'].fillna(train_df.reanalysis_specific_humidity_g_per_kg.mean(), inplace = True)
train_df['reanalysis_tdtr_k'].fillna(train_df.reanalysis_tdtr_k.mean(), inplace = True)
train_df['station_avg_temp_c'].fillna(train_df.station_avg_temp_c.mean(), inplace = True)
train_df['station_diur_temp_rng_c'].fillna(train_df.station_diur_temp_rng_c.mean(), inplace = True)
train_df['station_max_temp_c'].fillna(train_df.station_max_temp_c.mean(), inplace = True)
train_df['station_min_temp_c'].fillna(train_df.station_min_temp_c.mean(), inplace = True)
train_df['station_precip_mm'].fillna(train_df.station_precip_mm.mean(), inplace = True)

# %%
test_df['ndvi_ne'].fillna(test_df.ndvi_ne.mean(), inplace = True)
test_df['ndvi_nw'].fillna(test_df.ndvi_nw.mean(), inplace = True)
test_df['ndvi_se'].fillna(test_df.ndvi_se.mean(), inplace = True)
test_df['ndvi_sw'].fillna(test_df.ndvi_sw.mean(), inplace = True)
test_df['precipitation_amt_mm'].fillna(test_df.precipitation_amt_mm.mean(), inplace = True)
test_df['reanalysis_air_temp_k'].fillna(test_df.reanalysis_air_temp_k.mean(), inplace = True)
test_df['reanalysis_avg_temp_k'].fillna(test_df.reanalysis_avg_temp_k.mean(), inplace = True)
test_df['reanalysis_dew_point_temp_k'].fillna(test_df.reanalysis_max_air_temp_k.mean(), inplace = True)
test_df['reanalysis_max_air_temp_k'].fillna(test_df.reanalysis_dew_point_temp_k.mean(), inplace = True)
test_df['reanalysis_min_air_temp_k'].fillna(test_df.reanalysis_min_air_temp_k.mean(), inplace = True)
test_df['reanalysis_precip_amt_kg_per_m2'].fillna(test_df.reanalysis_precip_amt_kg_per_m2.mean(), inplace = True)
test_df['reanalysis_relative_humidity_percent'].fillna(test_df.reanalysis_relative_humidity_percent.mean(), inplace = True)
test_df['reanalysis_sat_precip_amt_mm'].fillna(test_df.reanalysis_sat_precip_amt_mm.mean(), inplace = True)
test_df['reanalysis_specific_humidity_g_per_kg'].fillna(test_df.reanalysis_specific_humidity_g_per_kg.mean(), inplace = True)
test_df['reanalysis_tdtr_k'].fillna(test_df.reanalysis_tdtr_k.mean(), inplace = True)
test_df['station_avg_temp_c'].fillna(test_df.station_avg_temp_c.mean(), inplace = True)
test_df['station_diur_temp_rng_c'].fillna(test_df.station_diur_temp_rng_c.mean(), inplace = True)
test_df['station_max_temp_c'].fillna(test_df.station_max_temp_c.mean(), inplace = True)
test_df['station_min_temp_c'].fillna(test_df.station_min_temp_c.mean(), inplace = True)
test_df['station_precip_mm'].fillna(test_df.station_precip_mm.mean(), inplace = True)

# %%
train_df.describe()
# Out:
#               year   weekofyear      ndvi_ne      ndvi_nw      ndvi_se  \
# count  1456.000000  1456.000000  1456.000000  1456.000000  1456.000000
# mean   2001.031593    26.503434     0.142294     0.130553     0.203783
# std       5.408314    15.019437     0.130827     0.117835     0.073299
# min    1990.000000     1.000000    -0.406250    -0.456100    -0.015533
# 25%    1997.000000    13.750000     0.055625     0.051367     0.155625
# 50%    2002.000000    26.500000     0.142294     0.128067     0.196998
# 75%    2005.000000    39.250000     0.229292     0.212325     0.247021
# max    2010.000000    53.000000     0.508357     0.454429     0.538314
#
#            ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  1456.000000           1456.000000            1456.000000
# mean      0.202305             45.760388             298.701852
# std       0.083266             43.519806               1.357730
# min      -0.063457              0.000000             294.635714
# ...

# %%
test_df.describe()
# Out:
#               year  weekofyear     ndvi_ne     ndvi_nw     ndvi_se  \
# count   416.000000  416.000000  416.000000  416.000000  416.000000
# mean   2010.766827   26.439904    0.126050    0.126803    0.207702
# std       1.434835   14.978257    0.155605    0.139533    0.079007
# min    2008.000000    1.000000   -0.463400   -0.211800    0.006200
# 25%    2010.000000   13.750000    0.008150    0.017188    0.148677
# 50%    2011.000000   26.000000    0.126050    0.099163    0.204479
# 75%    2012.000000   39.000000    0.248361    0.241182    0.254807
# max    2013.000000   53.000000    0.500400    0.649000    0.453043
#
#           ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  416.000000            416.000000             416.000000
# mean     0.201721             38.354324             298.818295
# std      0.091917             35.086274               1.465956
# min     -0.014671              0.000000             294.554286
# ...

# %%
train_label_df.describe()
# Out:
#               year   weekofyear  total_cases
# count  1456.000000  1456.000000  1456.000000
# mean   2001.031593    26.503434    24.675137
# std       5.408314    15.019437    43.596000
# min    1990.000000     1.000000     0.000000
# 25%    1997.000000    13.750000     5.000000
# 50%    2002.000000    26.500000    12.000000
# 75%    2005.000000    39.250000    28.000000
# max    2010.000000    53.000000   461.000000

# %%
train_df.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# 0  0.177617                 12.42             297.572857
# 1  0.155486                 22.82             298.211429
# 2  0.170843                 34.54             298.781429
# 3  0.235886                 15.36             298.987143
# 4  0.247340                  7.52             299.518571
#
#    reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# 0             297.742857                   292.414286
# 1             298.442857                   293.951429
# ...

# %%
train_df.drop('week_start_date',axis=1,inplace=True)
test_df.drop('week_start_date',axis=1,inplace=True)
train_df.head()
# Out:
#   city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0   sj  1990          18  0.122600  0.103725  0.198483  0.177617
# 1   sj  1990          19  0.169900  0.142175  0.162357  0.155486
# 2   sj  1990          20  0.032250  0.172967  0.157200  0.170843
# 3   sj  1990          21  0.128633  0.245067  0.227557  0.235886
# 4   sj  1990          22  0.196200  0.262200  0.251200  0.247340
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                 12.42             297.572857             297.742857
# 1                 22.82             298.211429             298.442857
# 2                 34.54             298.781429             298.878571
# 3                 15.36             298.987143             299.228571
# 4                  7.52             299.518571             299.664286
#
#    reanalysis_dew_point_temp_k  reanalysis_max_air_temp_k  \
# 0                   292.414286                      299.8
# ...

# %%
dlist = train_df.dtypes

# %%
train_df['city'].value_counts()
test_df['city'].value_counts()
# Out:
# sj    260
# iq    156
# Name: city, dtype: int64

# %%
my_dict = {"city":{"sj":1,"iq":2}}

# %%
train_df.replace(my_dict,inplace=True)
test_df.replace(my_dict,inplace=True)

# %%
train_df.head()
# Out:
#    city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0     1  1990          18  0.122600  0.103725  0.198483  0.177617
# 1     1  1990          19  0.169900  0.142175  0.162357  0.155486
# 2     1  1990          20  0.032250  0.172967  0.157200  0.170843
# 3     1  1990          21  0.128633  0.245067  0.227557  0.235886
# 4     1  1990          22  0.196200  0.262200  0.251200  0.247340
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                 12.42             297.572857             297.742857
# 1                 22.82             298.211429             298.442857
# 2                 34.54             298.781429             298.878571
# 3                 15.36             298.987143             299.228571
# 4                  7.52             299.518571             299.664286
#
#    reanalysis_dew_point_temp_k  reanalysis_max_air_temp_k  \
# 0                   292.414286                      299.8
# ...

# %%
cols = train_df.columns
index = train_df.index

# %%
index
# Out:
# RangeIndex(start=0, stop=1456, step=1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
#train_df=scaler.fit_transform(train_df)
#test_df=scaler.transform(test_df)

# %%
[type(train_df),type(test_df)]
# Out:
# [pandas.core.frame.DataFrame, pandas.core.frame.DataFrame]

# %%
#train_df=pd.DataFrame(train_df,columns=cols)
#test_df=pd.DataFrame(test_df,columns=cols)

# %%
random_index  = np.random.permutation(1456)
train_df = train_df.reindex(random_index)
train_label_df = train_label_df.reindex(random_index)

# %%
#Random forest

# %%
random_forest_model = RandomForestRegressor(n_estimators=100,oob_score=True,random_state=42)
random_forest_model.fit(train_df,train_label_df['total_cases'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=True, random_state=42, verbose=0, warm_start=False)

# %%
random_forest_model.oob_score_
# Out:
# 0.6807362926592845

# %%
y_oob = random_forest_model.oob_prediction_

# %%
y_oob
# Out:
# array([16.83870968,  5.2195122 , 58.04166667, ..., 15.05555556,
#        22.4516129 , 45.5952381 ])

# %%
y_predict = random_forest_model.predict(test_df)
y_predict = y_predict.round()
y_predict = y_predict.astype(int)

# %%
submit_random_forest = test_orig_df[['city','year','weekofyear']]
submit_random_forest['total_cases'] = y_predict
# Out:
# C:\Users\matibudd\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
submit_random_forest.to_csv('submit_random_forest_all_col.csv',index=False)
